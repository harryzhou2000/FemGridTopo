# %%
import matplotlib.pyplot as plt
import time
import numpy as np
import mpl_toolkits.mplot3d
import femRandInput

print(time.time())
rng = np.random.default_rng(0)
rng.normal()

nx = 100
ny = 100
xm,ym = np.meshgrid(np.arange(nx),np.arange(ny))

f = plt.figure(1)
ax = mpl_toolkits.mplot3d.Axes3D(auto_add_to_figure=False,fig=f)
f.add_axes(ax)
ax.view_init(elev=20,azim=25)
zm = femRandInput.gaussianWin2Oblique(nx,ny,100,1,np.pi*0.4)
fx = femRandInput.randBulkUni(nx,ny,win=femRandInput.gaussianWin2Oblique(40,40,1,10,np.pi*0.25))
ax.plot_surface(xm,ym,zm,cmap=plt.get_cmap('jet'))
ax.view_init(90)

f = plt.figure(2)
plt.pcolor(fx> 0.3)
np.sum(fx>0.0)/(nx*ny)
# n1 = 0.0
# for i in range(100):
#     fx = femRandInput.randBulkUni(nx,ny,win=femRandInput.gaussianWin2(60,60)) #femRandInput.gaussianWin2(60,60)
#     n1 += np.sum(fx>0.9)/(nx*ny)
# n1/100
# Out:
# 1638086197.3419259
# 0.5392

# %%
import numpy as np
import matplotlib.pyplot as plt
import femRandInput
nx = 100
ny = 100
a = np.random.rand(5,5)
a[[1,2]]
print(np.mod([122,333,333],[3,4,5]))

plt.pcolor(femRandInput.randDFSBulk(nx,ny,2000))
print(femRandInput.rng.integers(0,10))
print(np.maximum(0.5,a))
# Out:
# [2 1 3]
# 6
# [[0.5145115  0.5        0.5        0.5        0.68329019]
#  [0.5        0.78662455 0.8749034  0.5        0.5       ]
#  [0.5        0.5        0.5        0.61103125 0.5       ]
#  [0.5        0.73724376 0.5        0.90605357 0.82444665]
#  [0.88444911 0.67450643 0.5        0.5        0.5       ]]
