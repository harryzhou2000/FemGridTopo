# %%
import matplotlib.pyplot as plt
import femRandInput
import numpy as np

femRandInput.set_seed(1)

rhoGen = femRandInput.randRhoFilterGen(passes=[32,48,64,80])
bndGen = femRandInput.randBoundaryFilter1DGen(passes=[32,48,64,80])

# %%
rhoGen.genNext()
plt.pcolor(rhoGen.getRandCutDown())
plt.colorbar()

a = np.random.rand(5)

# %%
# femRandInput.set_seed(3)
bndGen.genNext()
bnddata = bndGen.getRandCutDownMat()
bnddata2 = bndGen.getBinaryMat(fltrange=0.9)
plt.pcolor(bnddata2)
plt.colorbar()
# print(bnddata2.dtype)
a = np.random.rand(5)
print(a)
print(np.roll(a,1,axis=0))

print(bndGen.examineBinaryPortion(), bndGen.nb)
plt.figure(3)
plt.pcolor(bndGen.getBinarySupportRho())
# Out:
# [0.29867864 0.52706089 0.30289085 0.18237989 0.03428621]
# [0.03428621 0.29867864 0.52706089 0.30289085 0.18237989]
# (0.22265625, 0.5703125, 0.20703125) 256
