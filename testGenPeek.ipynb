# %%
import numpy as np
import femDataGen
import femRandInput
import time,os

generator = femDataGen.femDataGenFilterCut(nx=64, ny=64) 

generator.loadData('data/test_opt', seqTarget=9)

# %%
import matplotlib.pyplot as plt
case = generator.getOneCase(123,15)
draws = ['fix','rho','fx','fy','u','v','da']
for drawname in draws:
    plt.figure(drawname)
    plt.pcolor(case[drawname])
    plt.colorbar()
