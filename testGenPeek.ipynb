# %%
import numpy as np
import femDataGen
import femRandInput
import time,os

generator = femDataGen.femDataGenFilterCut(nx=64, ny=64) 

generator.loadData('data/test_opt', seqTarget=0)

# %%
import matplotlib.pyplot as plt
case = generator.getOneCase(1,10)
draws = ['fix','rho','fx','fy','u','v','vm']
for drawname in draws:
    plt.figure(drawname)
    plt.pcolor(case[drawname])
    plt.colorbar()
