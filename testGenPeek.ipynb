# %%
import numpy as np
import femDataGen
import femRandInput
import time,os

generator = femDataGen.femDataGenFilterCut(nx=64, ny=64) 

generator.loadData('data/test_static', seqTarget=2)

# %%
import matplotlib.pyplot as plt
case = generator.getOneCase(0,3,False)
draws = ['fix','rho','fx','fy','u','v']
for drawname in draws:
    plt.figure(drawname)
    plt.pcolor(case[drawname])
    plt.colorbar()
